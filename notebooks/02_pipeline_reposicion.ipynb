# %% [markdown]
# # 02 — Pipeline de reposición (Sugerido de Compras)
#
# Flujo: KPIs → ABCI → cantidad a comprar → Excel.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.generate_synthetic import generate_all
from src.pipeline import run_pipeline

generate_all(out_dir=ROOT / 'data' / 'synthetic')
df = run_pipeline()
df[['sku','abci','modo_compra','stock_total','lead_time','unidades_mediana_12m','cantidad_a_comprar','costo_total']].head(20)

# %%
print('SKUs con compra > 0:', (df.cantidad_a_comprar > 0).sum())
print('Costo total:', round(df.costo_total.sum(), 2))
df.abci.value_counts()
