# %% [markdown]
# # 04 — Tour de un SKU
#
# Elegimos un SKU con demanda clara y desglosamos la fórmula. Ver también `docs/tour-un-sku.md`.

# %%
import sys
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.replenishment import qty_standard, qty_plaza

df = pd.read_csv(ROOT/'output'/'sugerido_compras.csv')
row = df.sort_values('unidades_mediana_12m', ascending=False).iloc[0]
print(row[['sku','descripcion','abci','modo_compra','lead_time','stock_total','solicitados','embarcados','internados','unidades_mediana_12m','unidades_promedio_12m','cantidad_a_comprar']])

if row.modo_compra == 'plaza':
    manual = qty_plaza(row.unidades_promedio_12m, row.stock_total)
else:
    manual = qty_standard(row.unidades_mediana_12m, row.lead_time, row.stock_total, row.internados, row.solicitados, row.embarcados)
print('Recálculo manual:', manual, '| Pipeline:', row.cantidad_a_comprar)
