# %% [markdown]
# # 03 — ABCI explicado
#
# **Analogía:** ordenas la despensa por cuánto usas cada cosa.
# - **S**: arroz/aceite (si falta, se nota)
# - **A/B**: útil pero no tanto
# - **C**: raramente usado
# - **I**: hace meses que no se toca
#
# En ventas, el Pareto suele decir: pocos SKUs explican la mayor parte de la plata.

# %%
import sys
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.abci import classify_abci

df = pd.read_csv(ROOT/'output'/'sugerido_compras.csv')
print(df.abci.value_counts())
df.groupby('abci')[['ventas_6m','cantidad_a_comprar','costo_total']].sum().round(1)
