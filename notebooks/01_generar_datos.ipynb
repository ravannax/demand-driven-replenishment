# %% [markdown]
# # 01 — Generar datos sintéticos
#
# Creamos 100 SKUs ficticios, 3 locales y 12 meses de ventas.
# El **seed** hace que el resultado sea siempre el mismo al clonar el repo.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.generate_synthetic import generate_all

tables = generate_all(seed=42, n_skus=100, months=12, out_dir=ROOT / 'data' / 'synthetic')
for k,v in tables.items():
    print(f'{k}: {len(v):,} filas')
tables['products'].head()

# %% [markdown]
# ## ¿Por qué sintéticos?
# Para publicar el portafolio **sin violar NDA**. La lógica es la misma idea usada sobre >70k SKUs reales; los números de aquí son inventados.
